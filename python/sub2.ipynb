# %%
from image_process import *

# %%
img1 = img_load('3.jpg', 'rgb')
img2 = img_load('3.jpg', 'cmyk')
img3 = img_load('3.jpg', 'hsv')

# %%
R, G, B = split_ch(img1)
C, M, Y, K = split_ch(img2)
H, S, V = split_ch(img3)

# %%
H1 = gaussian(H)
H2 = posterizing(H1, 5)

# %%
h2_edge = sobel_edge_detection(H2, single_channel = True)

# %%
R1 = gaussian(R)
R2 = posterizing(R1, 5)

# %%
R2_edge = sobel_edge_detection(R2, single_channel = True)

# %%
imshow(R2, 'Reds_r')

# %%
img1_edge = sobel_edge_detection(img1)
